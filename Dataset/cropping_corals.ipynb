# %% [markdown]
# # Cropping images automatically

# %%
import os
import pandas as pandas
import cv2

# %%
# directories
raw_dirs = [
    r"E:\DLSU\Corallian\Dataset\C-30\SHINE-1739(SanDiegoA)\RAW\Olympus TG6 CBRACT 2_01",
    r"E:\DLSU\Corallian\Dataset\C-30\SHINE-1739(SanDiegoA)\RAW\Olympus TG6 CBRACT 2_02",
]

scored_dir = r"E:\DLSU\Corallian\Dataset\C-30\SHINE-1739(SanDiegoA)\SCORED"
output_dir = r"E:\DLSU\Corallian\Dataset\cropped-corals"

# create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# %%
crop_size = 500
half_crop = crop_size // 2

# %%
# function to find full path of an image

def find_image(image_name, raw_dirs):
    for raw_dir in raw_dirs:
        image_path = os.path.join(raw_dir, image_name)
        if os.path.exists(image_path):
            return image_path
    return None

# %%
# Process each CPCE annotation file
for annotation_file in os.listdir(scored_dir):
    if annotation_file.endswith(".cpce"):
        continue

    annotation_path = os.path.join(scored_dir, annotation_file)
    print(f"Processing: {annotation_path}")

    # Parse the annotation file
    with open(annotation_path, "r") as file:
        lines = file.readlines()

    try:
        # Extract image name
        image_name = os.path.basename(lines[0].split(",")[1].strip('"'))

        # Find the line containing "0,0" to locate the start of the annotations
        start_index = None
        for i, line in enumerate(lines):
            if line.strip() == "0,0":
                start_index = i + 1
                break

        if start_index is None:
            print(f"Skipping file {annotation_file}: '0,0' marker not found.")
            continue

        # Parse the number of annotations
        try:
            num_annotations = int(lines[start_index].strip())
        except ValueError:
            print(f"Skipping file {annotation_file} due to invalid number of annotations.")
            continue

        if num_annotations <= 0:
            print(f"Skipping file {annotation_file} due to zero or negative annotations.")
            continue

        # Extract points and labels
        points = []
        labels = []
        for i in range(num_annotations):
            point_line = lines[start_index + 1 + i].strip()
            label_line = lines[start_index + 1 + num_annotations + i].strip()

            try:
                # Parse point coordinates
                x, y = map(int, point_line.split(","))
                points.append((x, y))

                # Parse label
                label = label_line.split(",")[1].strip('"')
                labels.append(label)
            except (ValueError, IndexError):
                print(f"Skipping invalid line in file {annotation_file}: {point_line} or {label_line}")

    except Exception as e:
        print(f"Error parsing annotation file {annotation_file}: {e}")
        continue

    # Find the corresponding image
    image_path = find_image(image_name, raw_dirs)
    if not image_path:
        print(f"Image not found: {image_name}")
        continue

    # Load the image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Failed to load image: {image_path}")
        continue

    # Crop and save each annotation
    for i, (point, label) in enumerate(zip(points, labels)):
        x, y = point

        # Define crop boundaries
        x_min = max(0, x - half_crop)
        y_min = max(0, y - half_crop)
        x_max = min(image.shape[1], x + half_crop)
        y_max = min(image.shape[0], y + half_crop)

        # Check for valid crop (not empty)
        if x_min >= x_max or y_min >= y_max:
            print(f"Skipping invalid crop at ({x}, {y}) in image {image_name}. Crop is empty.")
            continue

        # Crop the image
        cropped = image[y_min:y_max, x_min:x_max]

        # Check if cropped image is empty
        if cropped.size == 0:
            print(f"Skipping empty crop for {label}_{os.path.splitext(image_name)[0]}_{i}.jpg")
            continue

        # Save the cropped image
        output_path = os.path.join(output_dir, f"{label}_{os.path.splitext(image_name)[0]}_{i}.jpg")
        cv2.imwrite(output_path, cropped)
        print(f"Saved: {output_path}")

print("Cropping complete!")
# Out:
# Processing: E:\DLSU\Corallian\Dataset\C-30\SHINE-1739(SanDiegoA)\SCORED\PB100151.cpc
# Skipping invalid crop at (54640, 32169) in image PB100151.JPG. Crop is empty.
# Skipping invalid crop at (45699, 5082) in image PB100151.JPG. Crop is empty.
# Skipping invalid crop at (10830, 21703) in image PB100151.JPG. Crop is empty.
# Skipping invalid crop at (8235, 41829) in image PB100151.JPG. Crop is empty.
# Skipping invalid crop at (36247, 33230) in image PB100151.JPG. Crop is empty.
# Skipping invalid crop at (46413, 9229) in image PB100151.JPG. Crop is empty.
# Skipping invalid crop at (20628, 5277) in image PB100151.JPG. Crop is empty.
# Skipping invalid crop at (19278, 11437) in image PB100151.JPG. Crop is empty.
# Skipping invalid crop at
JPG. Crop is empty.
# Processing: E:\DLSU\Corallian\Dataset\C-30\SHINE-1739(SanDiegoA)\SCORED\PB100174.cpc
# Skipping invalid crop at (44505, 6136) in image PB100174.JPG. Crop is empty.
# Skipping invalid crop at (41483, 31777) in image PB100174.JPG. Crop is empty.
# Skipping invalid crop at (53430, 122) in image PB100174.JPG. Crop is empty.
# Skipping invalid crop at (38271, 36765) in image PB100174.JPG. Crop is empty.
# Skipping invalid crop at (36583, 23100) in image PB100174.JPG. Crop is empty.
# Skipping invalid crop at (49971, 30616) in image PB100174.JPG. Crop is empty.
# Skipping invalid crop at (8890, 43316) in image PB100174.JPG. Crop is empty.
# Skipping invalid crop at (36642, 21055) in image PB100174.JPG. Crop is empty.
# Skipping invalid crop at (59778, 8959) in image PB100174.JPG. Crop is empty.
# Skipping invalid crop at (13309, 1789) in image PB100174.JPG. Crop is empty.
# Processing: E:\DLSU\Corallian\Dataset\C-30\SHINE-1739(SanDiegoA)\SCORED\PB100175.cpc
# Skipping invalid crop at (34093, 22787) in image PB100175.JPG. Crop is empty.
# Skipping invalid crop at (9476, 37338) in image PB100175.JPG. Crop is empty.
# Skipping invalid crop at (51965, 25398) in image PB100175.JPG. Crop is empty.
# Skipping invalid crop at (12326, 35750) in image PB100175.JPG. Crop is empty.
# Skipping invalid crop at (37091, 34020) in image PB100175.JPG. Crop is empty.
# Skipping invalid crop at (56119, 36460) in image PB100175.JPG. Crop is empty.
# Skipping invalid crop at (14085, 28609) in image PB100175.JPG. Crop is empty.
# Skipping invalid crop at (11790, 1023) in image PB100175.JPG. Crop is empty.
# Skipping invalid crop at (36332, 2518) in image PB100175.JPG. Crop is empty.
# Skipping invalid crop at (54525, 1745) in image PB100175.JPG. Crop is empty.
# Processing: E:\DLSU\Corallian\Dataset\C-30\SHINE-1739(SanDiegoA)\SCORED\PB103584.cpc
# Skipping invalid crop at (43384, 34249) in image PB103584.JPG. Crop is empty.
# Skipping invalid crop at (19802, 37586) in image PB103584.JPG. Crop is empty.
# Skipping invalid crop at (40688, 12880) in image PB103584.JPG. Crop is empty.
# Skipping invalid crop at (28436, 35242) in image PB103584.JPG. Crop is empty.
# Skipping invalid crop at (35113, 42962) in image PB103584.JPG. Crop is empty.
# Skipping invalid crop at (29142, 22958) in image PB103584.JPG. Crop is empty.
# Skipping invalid crop at (37946, 19027) in image PB103584.JPG. Crop is empty.
# Skipping invalid crop at (2996, 40787) in image PB103584.JPG. Crop is empty.
# Skipping invalid crop at (44834, 36726) in image PB103584.JPG. Crop is empty.
# Skipping invalid crop at (2483, 22898) in image PB103584.JPG. Crop is empty.
# Processing: E:\DLSU\Corallian\Dataset\C-30\SHINE-1739(SanDiegoA)\SCORED\PB103586.cpc
# Skipping invalid crop at (36120, 3852) in image PB103586.JPG. Crop is empty.
# Skipping invalid crop at (15367, 36011) in image PB103586.JPG. Crop is empty.
# Skipping invalid crop at (17353, 22458) in image PB103586.JPG. Crop is empty.
# Skipping invalid crop at (45472, 13179) in image PB103586.JPG. Crop is empty.
# Skipping invalid crop at (28197, 20949) in image PB103586.JPG. Crop is empty.
# Skipping invalid crop at (47517, 30368) in image PB103586.JPG. Crop is empty.
# Skipping invalid crop at (29045, 6854) in image PB103586.JPG. Crop is empty.
# Skipping invalid crop at (52781, 31897) in image PB103586.JPG. Crop is empty.
# Skipping invalid crop at (26617, 16978) in image PB103586.JPG. Crop is empty.
# Skipping invalid crop at (37311, 12472) in image PB103586.JPG. Crop is empty.
# Processing: E:\DLSU\Corallian\Dataset\C-30\SHINE-1739(SanDiegoA)\SCORED\PB103587.cpc
# Skipping invalid crop at (24435, 21284) in image PB103587.JPG. Crop is empty.
# Skipping invalid crop at (32238, 12811) in image PB103587.JPG. Crop is empty.
# Skipping invalid crop at (5253, 11555) in image PB103587.JPG. Crop is empty.
# Skipping invalid crop at (51558, 7020) in image PB103587.JPG. Crop is empty.
# Skipping invalid crop at (32654, 30070) in image PB103587.JPG. Crop is empty.
# Skipping invalid crop at (21656, 33585) in image PB103587.JPG. Crop is empty.
# Skipping invalid crop at (41054, 35288) in image PB103587.JPG. Crop is empty.
# Skipping invalid crop at (1729, 19949) in image PB103587.JPG. Crop is empty.
# Skipping invalid crop at (27813, 29494) in image PB103587.JPG. Crop is empty.
# Skipping invalid crop at (10970, 44134) in image PB103587.JPG. Crop is empty.
# Processing: E:\DLSU\Corallian\Dataset\C-30\SHINE-1739(SanDiegoA)\SCORED\PB103588.cpc
# Skipping invalid crop at (6949, 39321) in image PB103588.JPG. Crop is empty.
# Skipping invalid crop at (16124, 39180) in image PB103588.JPG. Crop is empty.
# Skipping invalid crop at (29184, 6732) in image PB103588.JPG. Crop is empty.
# Skipping invalid crop at (34564, 25119) in image PB103588.JPG. Crop is empty.
# Skipping invalid crop at (56654, 23926) in image PB103588.JPG. Crop is empty.
# Skipping invalid crop at (44508, 6856) in image PB103588.JPG. Crop is empty.
# Skipping invalid crop at (55454, 4855) in image PB103588.JPG. Crop is empty.
# Skipping invalid crop at (52388, 15384) in image PB103588.JPG. Crop is empty.
# Skipping invalid crop at (48788, 22297) in image PB103588.JPG. Crop is empty.
# Skipping invalid crop at (10053, 7220) in image PB103588.JPG. Crop is empty.
# Processing: E:\DLSU\Corallian\Dataset\C-30\SHINE-1739(SanDiegoA)\SCORED\PB103589.cpc
# Skipping invalid crop at (35622, 10775) in image PB103589.JPG. Crop is empty.
# Skipping invalid crop at (13582, 2133) in image PB103589.JPG. Crop is empty.
# Skipping invalid crop at (31130, 41160) in image PB103589.JPG. Crop is empty.
# Skipping invalid crop at (56519, 19301) in image PB103589.JPG. Crop is empty.
# Skipping invalid crop at (21387, 4608) in image PB103589.JPG. Crop is empty.
# Skipping invalid crop at (49059, 44603) in image PB103589.JPG. Crop is empty.
# Skipping invalid crop at (11551, 33778) in image PB103589.JPG. Crop is empty.
# Skipping invalid crop at (17134, 7566) in image PB103589.JPG. Crop is empty.
# Skipping invalid crop at (29033, 37612) in image PB103589.JPG. Crop is empty.
# Skipping invalid crop at (42552, 11707) in image PB103589.JPG. Crop is empty.
# Processing: E:\DLSU\Corallian\Dataset\C-30\SHINE-1739(SanDiegoA)\SCORED\PB103594.cpc
# Skipping invalid crop at (51804, 39534) in image PB103594.JPG. Crop is empty.
# Skipping invalid crop at (35196, 2676) in image PB103594.JPG. Crop is empty.
# Skipping invalid crop at (53319, 43825) in image PB103594.JPG. Crop is empty.
# Skipping invalid crop at (28744, 4093) in image PB103594.JPG. Crop is empty.
# Skipping invalid crop at (42582, 22383) in image PB103594.JPG. Crop is empty.
# Skipping invalid crop at (43532, 40413) in image PB103594.JPG. Crop is empty.
# Skipping invalid crop at (37999, 19930) in image PB103594.JPG. Crop is empty.
# Skipping invalid crop at (58173, 5882) in image PB103594.JPG. Crop is empty.
# Saved: E:\DLSU\Corallian\Dataset\cropped-corals\AA_PB103594_8.jpg
# Skipping invalid crop at (51217, 16192) in image PB103594.JPG. Crop is empty.
# Processing: E:\DLSU\Corallian\Dataset\C-30\SHINE-1739(SanDiegoA)\SCORED\PB103597.cpc
# Skipping invalid crop at (28260, 33981) in image PB103597.JPG. Crop is empty.
# Skipping invalid crop at (16068, 10641) in image PB103597.JPG. Crop is empty.
# Skipping invalid crop at (20711, 14750) in image PB103597.JPG. Crop is empty.
# Skipping invalid crop at (2464, 33737) in image PB103597.JPG. Crop is empty.
# Skipping invalid crop at (6780, 41281) in image PB103597.JPG. Crop is empty.
# Skipping invalid crop at (36933, 7133) in image PB103597.JPG. Crop is empty.
# Skipping invalid crop at (34753, 17041) in image PB103597.JPG. Crop is empty.
# Skipping invalid crop at (18901, 42528) in image PB103597.JPG. Crop is empty.
# Skipping invalid crop at (3989, 10865) in image PB103597.JPG. Crop is empty.
# Skipping invalid crop at (34086, 6319) in image PB103597.JPG. Crop is empty.
# Cropping complete!
